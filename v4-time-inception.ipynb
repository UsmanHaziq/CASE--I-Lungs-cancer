# %% [markdown]
# <a href="https://colab.research.google.com/github/UsmanHaziq/CASE--I-Lungs-cancer/blob/main/v4-time-inception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.layers import Dense, GlobalAveragePooling2D
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf

# !pip install tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.36.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
# Load the data
train_set = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/lungs cancer inmol/Train",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 357 files belonging to 3 classes.

# %%
val_set = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/lungs cancer inmol/Val",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 77 files belonging to 3 classes.

# %%
test_set = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/MyDrive/lungs cancer inmol/Test",
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 76 files belonging to 3 classes.

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import numpy as np

# Define class names
class_names = ['Training set', 'Validation set', 'Test set']

# Get the number of samples in each set
labels_count = [len(train_set), len(val_set), len(test_set)]

# Create the pie chart
plt.figure(figsize=(16, 16))
plt.pie(labels_count, labels=class_names, startangle=180,
        autopct='%1.1f%%', colors=['#00ff99', '#FF96A7',"beige"], shadow=True)
plt.title('Distribution of Data', fontsize=20)
plt.show()

# %%
class_names = ['Adenocarcinoma', 'Benign', 'Squamous_carcinoma']
print(class_names)
# Out:
# ['Adenocarcinoma', 'Benign', 'Squamous_carcinoma']

# %%
for image_batch, label_batch in train_set:
    print(image_batch.shape)
    break
# Out:
# (32, 224, 224, 3)

# %%
IMAGE_SIZE = [224, 224]


# Load the InceptionV3 model
inception = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# %%
# don't train existing weights
for layer in inception.layers:
    layer.trainable = False

# %%
# Add your own layers
x = GlobalAveragePooling2D()(inception.output)
x = Dense(1024, activation='relu')(x)  # You can add more dense layers if needed
prediction = Dense(3, activation='softmax')(x)  # Assuming you have 3 classes
# Create a model object
model = Model(inputs=inception.input, outputs=prediction)
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_191 (Conv2D)         (None, 111, 111, 32)         864       ['input_3[0][0]']
#
#  batch_normalization_188 (B  (None, 111, 111, 32)         96        ['conv2d_191[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 111, 111, 32)         0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (None, 109, 109, 32)         9216      ['activation_188[0][0]']
#
#  batch_normalization_189 (B  (None, 109, 109, 32)         96        ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 109, 109, 32)         0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 109, 109, 64)         18432     ['activation_189[0][0]']
#
#  batch_normalization_190 (B  (None, 109, 109, 64)         192       ['conv2d_193[0][0]']
#  atchNormalization)
#
#  activation_190 (Activation  (None, 109, 109, 64)         0         ['batch_normalization_190[0][0
#  )                                                                  ]']
#
#  max_pooling2d_11 (MaxPooli  (None, 54, 54, 64)           0         ['activation_190[0][0]']
#  ng2D)
#
#  conv2d_194 (Conv2D)         (None, 54, 54, 80)           5120      ['max_pooling2d_11[0][0]']
#
#  batch_normalization_191 (B  (None, 54, 54, 80)           240       ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 54, 54, 80)           0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 52, 52, 192)          138240    ['activation_191[0][0]']
#
#  batch_normalization_192 (B  (None, 52, 52, 192)          576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 52, 52, 192)          0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  max_pooling2d_12 (MaxPooli  (None, 25, 25, 192)          0         ['activation_192[0][0]']
#  ng2D)
#
#  conv2d_199 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_196 (B  (None, 25, 25, 64)           192       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 25, 25, 48)           9216      ['max_pooling2d_12[0][0]']
#
#  conv2d_200 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_196[0][0]']
#
#  batch_normalization_194 (B  (None, 25, 25, 48)           144       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  batch_normalization_197 (B  (None, 25, 25, 96)           288       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_194 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  activation_197 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  average_pooling2d_18 (Aver  (None, 25, 25, 192)          0         ['max_pooling2d_12[0][0]']
#  agePooling2D)
#
#  conv2d_196 (Conv2D)         (None, 25, 25, 64)           12288     ['max_pooling2d_12[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_194[0][0]']
#
#  conv2d_201 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_197[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 25, 25, 32)           6144      ['average_pooling2d_18[0][0]']
#
#  batch_normalization_193 (B  (None, 25, 25, 64)           192       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  batch_normalization_195 (B  (None, 25, 25, 64)           192       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 25, 25, 96)           288       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  batch_normalization_199 (B  (None, 25, 25, 32)           96        ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  activation_195 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  activation_199 (Activation  (None, 25, 25, 32)           0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 25, 25, 256)          0         ['activation_193[0][0]',
#                                                                      'activation_195[0][0]',
#                                                                      'activation_198[0][0]',
#                                                                      'activation_199[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_203 (B  (None, 25, 25, 64)           192       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  conv2d_204 (Conv2D)         (None, 25, 25, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_207 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_203[0][0]']
#
#  batch_normalization_201 (B  (None, 25, 25, 48)           144       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  batch_normalization_204 (B  (None, 25, 25, 96)           288       ['conv2d_207[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  activation_204 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  average_pooling2d_19 (Aver  (None, 25, 25, 256)          0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_203 (Conv2D)         (None, 25, 25, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_205 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_201[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_204[0][0]']
#
#  conv2d_209 (Conv2D)         (None, 25, 25, 64)           16384     ['average_pooling2d_19[0][0]']
#
#  batch_normalization_200 (B  (None, 25, 25, 64)           192       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 25, 25, 64)           192       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  batch_normalization_205 (B  (None, 25, 25, 96)           288       ['conv2d_208[0][0]']
#  atchNormalization)
#
#  batch_normalization_206 (B  (None, 25, 25, 64)           192       ['conv2d_209[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  activation_205 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  activation_206 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 25, 25, 288)          0         ['activation_200[0][0]',
#                                                                      'activation_202[0][0]',
#                                                                      'activation_205[0][0]',
#                                                                      'activation_206[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_210 (B  (None, 25, 25, 64)           192       ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_210 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 25, 25, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_214 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_210[0][0]']
#
#  batch_normalization_208 (B  (None, 25, 25, 48)           144       ['conv2d_211[0][0]']
#  atchNormalization)
#
#  batch_normalization_211 (B  (None, 25, 25, 96)           288       ['conv2d_214[0][0]']
#  atchNormalization)
#
#  activation_208 (Activation  (None, 25, 25, 48)           0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  activation_211 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  average_pooling2d_20 (Aver  (None, 25, 25, 288)          0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_210 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 25, 25, 64)           76800     ['activation_208[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 25, 25, 96)           82944     ['activation_211[0][0]']
#
#  conv2d_216 (Conv2D)         (None, 25, 25, 64)           18432     ['average_pooling2d_20[0][0]']
#
#  batch_normalization_207 (B  (None, 25, 25, 64)           192       ['conv2d_210[0][0]']
#  atchNormalization)
#
#  batch_normalization_209 (B  (None, 25, 25, 64)           192       ['conv2d_212[0][0]']
#  atchNormalization)
#
#  batch_normalization_212 (B  (None, 25, 25, 96)           288       ['conv2d_215[0][0]']
#  atchNormalization)
#
#  batch_normalization_213 (B  (None, 25, 25, 64)           192       ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_207 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  activation_209 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  activation_212 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  activation_213 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 25, 25, 288)          0         ['activation_207[0][0]',
#                                                                      'activation_209[0][0]',
#                                                                      'activation_212[0][0]',
#                                                                      'activation_213[0][0]']
#
#  conv2d_218 (Conv2D)         (None, 25, 25, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_215 (B  (None, 25, 25, 64)           192       ['conv2d_218[0][0]']
#  atchNormalization)
#
#  activation_215 (Activation  (None, 25, 25, 64)           0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  conv2d_219 (Conv2D)         (None, 25, 25, 96)           55296     ['activation_215[0][0]']
#
#  batch_normalization_216 (B  (None, 25, 25, 96)           288       ['conv2d_219[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 25, 25, 96)           0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_217 (Conv2D)         (None, 12, 12, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_220 (Conv2D)         (None, 12, 12, 96)           82944     ['activation_216[0][0]']
#
#  batch_normalization_214 (B  (None, 12, 12, 384)          1152      ['conv2d_217[0][0]']
#  atchNormalization)
#
#  batch_normalization_217 (B  (None, 12, 12, 96)           288       ['conv2d_220[0][0]']
#  atchNormalization)
#
#  activation_214 (Activation  (None, 12, 12, 384)          0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  activation_217 (Activation  (None, 12, 12, 96)           0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  max_pooling2d_13 (MaxPooli  (None, 12, 12, 288)          0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 12, 12, 768)          0         ['activation_214[0][0]',
#                                                                      'activation_217[0][0]',
#                                                                      'max_pooling2d_13[0][0]']
#
#  conv2d_225 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_222 (B  (None, 12, 12, 128)          384       ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  conv2d_226 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_222[0][0]']
#
#  batch_normalization_223 (B  (None, 12, 12, 128)          384       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_222 (Conv2D)         (None, 12, 12, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_227 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_223[0][0]']
#
#  batch_normalization_219 (B  (None, 12, 12, 128)          384       ['conv2d_222[0][0]']
#  atchNormalization)
#
#  batch_normalization_224 (B  (None, 12, 12, 128)          384       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_219[0][0
#  )                                                                  ]']
#
#  activation_224 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_223 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_219[0][0]']
#
#  conv2d_228 (Conv2D)         (None, 12, 12, 128)          114688    ['activation_224[0][0]']
#
#  batch_normalization_220 (B  (None, 12, 12, 128)          384       ['conv2d_223[0][0]']
#  atchNormalization)
#
#  batch_normalization_225 (B  (None, 12, 12, 128)          384       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  activation_225 (Activation  (None, 12, 12, 128)          0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  average_pooling2d_21 (Aver  (None, 12, 12, 768)          0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_221 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_220[0][0]']
#
#  conv2d_229 (Conv2D)         (None, 12, 12, 192)          172032    ['activation_225[0][0]']
#
#  conv2d_230 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_21[0][0]']
#
#  batch_normalization_218 (B  (None, 12, 12, 192)          576       ['conv2d_221[0][0]']
#  atchNormalization)
#
#  batch_normalization_221 (B  (None, 12, 12, 192)          576       ['conv2d_224[0][0]']
#  atchNormalization)
#
#  batch_normalization_226 (B  (None, 12, 12, 192)          576       ['conv2d_229[0][0]']
#  atchNormalization)
#
#  batch_normalization_227 (B  (None, 12, 12, 192)          576       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  activation_221 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  activation_226 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  activation_227 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 12, 12, 768)          0         ['activation_218[0][0]',
#                                                                      'activation_221[0][0]',
#                                                                      'activation_226[0][0]',
#                                                                      'activation_227[0][0]']
#
#  conv2d_235 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_232 (B  (None, 12, 12, 160)          480       ['conv2d_235[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_236 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_232[0][0]']
#
#  batch_normalization_233 (B  (None, 12, 12, 160)          480       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_232 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_237 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_233[0][0]']
#
#  batch_normalization_229 (B  (None, 12, 12, 160)          480       ['conv2d_232[0][0]']
#  atchNormalization)
#
#  batch_normalization_234 (B  (None, 12, 12, 160)          480       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  activation_234 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_229[0][0]']
#
#  conv2d_238 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_234[0][0]']
#
#  batch_normalization_230 (B  (None, 12, 12, 160)          480       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  batch_normalization_235 (B  (None, 12, 12, 160)          480       ['conv2d_238[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  activation_235 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  average_pooling2d_22 (Aver  (None, 12, 12, 768)          0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_231 (Conv2D)         (None, 12, 12, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_234 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_230[0][0]']
#
#  conv2d_239 (Conv2D)         (None, 12, 12, 192)          215040    ['activation_235[0][0]']
#
#  conv2d_240 (Conv2D)         (None, 12, 12, 192)          147456    ['average_pooling2d_22[0][0]']
#
#  batch_normalization_228 (B  (None, 12, 12, 192)          576       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  batch_normalization_231 (B  (None, 12, 12, 192)          576       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  batch_normalization_236 (B  (None, 12, 12, 192)          576       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  batch_normalization_237 (B  (None, 12, 12, 192)          576       ['conv2d_240[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  activation_231 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  activation_236 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  activation_237 (Activation  (None, 12, 12, 192)          0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 12, 12, 768)          0         ['activation_228[0][0]',
#                                                                      'activation_231[0][0]',
#                                                                      'activation_236[0][0]',
#                                                                      'activation_237[0][0]']
#
#  conv2d_245 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_242 (B  (None, 12, 12, 160)          480       ['conv2d_245[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_246 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_242[0][0]']
#
#  batch_normalization_243 (B  (None, 12, 12, 160)          480       ['conv2d_246[0][0]']
#  atchNormalization)
#
#  activation_243 (Activation  (None, 12, 12, 160)          0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_242 (Conv2D)         (None, 12, 12, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_247 (Conv2D)         (None, 12, 12, 160)          179200    ['activation_243[0][0]']
#
#  batch_normalization_239 (B  (None, 12, 12, 160)          480       ['conv2d_242[0][0]']
#  atchNormalization)
#
#  batch_normalization_244 (B  (None, 12, 12, 160)          480       ['conv2d_247[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_269 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_265[0][0]']
#
#  conv2d_270 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_265[0][0]']
#
#  conv2d_273 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_269[0][0]']
#
#  conv2d_274 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_269[0][0]']
#
#  average_pooling2d_25 (Aver  (None, 5, 5, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_267 (Conv2D)         (None, 5, 5, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_266 (B  (None, 5, 5, 384)            1152      ['conv2d_269[0][0]']
#  atchNormalization)
#
#  batch_normalization_267 (B  (None, 5, 5, 384)            1152      ['conv2d_270[0][0]']
#  atchNormalization)
#
#  batch_normalization_270 (B  (None, 5, 5, 384)            1152      ['conv2d_273[0][0]']
#  atchNormalization)
#
#  batch_normalization_271 (B  (None, 5, 5, 384)            1152      ['conv2d_274[0][0]']
#  atchNormalization)
#
#  conv2d_275 (Conv2D)         (None, 5, 5, 192)            245760    ['average_pooling2d_25[0][0]']
#
#  batch_normalization_264 (B  (None, 5, 5, 320)            960       ['conv2d_267[0][0]']
#  atchNormalization)
#
#  activation_266 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_266[0][0
#  )                                                                  ]']
#
#  activation_267 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_267[0][0
#  )                                                                  ]']
#
#  activation_270 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_270[0][0
#  )                                                                  ]']
#
#  activation_271 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_271[0][0
#  )                                                                  ]']
#
#  batch_normalization_272 (B  (None, 5, 5, 192)            576       ['conv2d_275[0][0]']
#  atchNormalization)
#
#  activation_264 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_264[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 5, 5, 768)            0         ['activation_266[0][0]',
#                                                                      'activation_267[0][0]']
#
#  concatenate_4 (Concatenate  (None, 5, 5, 768)            0         ['activation_270[0][0]',
#  )                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_272[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 5, 5, 2048)           0         ['activation_264[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_4[0][0]',
#                                                                      'activation_272[0][0]']
#
#  conv2d_280 (Conv2D)         (None, 5, 5, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_277 (B  (None, 5, 5, 448)            1344      ['conv2d_280[0][0]']
#  atchNormalization)
#
#  activation_277 (Activation  (None, 5, 5, 448)            0         ['batch_normalization_277[0][0
#  )                                                                  ]']
#
#  conv2d_277 (Conv2D)         (None, 5, 5, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_281 (Conv2D)         (None, 5, 5, 384)            1548288   ['activation_277[0][0]']
#
#  batch_normalization_274 (B  (None, 5, 5, 384)            1152      ['conv2d_277[0][0]']
#  atchNormalization)
#
#  batch_normalization_278 (B  (None, 5, 5, 384)            1152      ['conv2d_281[0][0]']
#  atchNormalization)
#
#  activation_274 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_274[0][0
#  )                                                                  ]']
#
#  activation_278 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_278[0][0
#  )                                                                  ]']
#
#  conv2d_278 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_274[0][0]']
#
#  conv2d_279 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_274[0][0]']
#
#  conv2d_282 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_278[0][0]']
#
#  conv2d_283 (Conv2D)         (None, 5, 5, 384)            442368    ['activation_278[0][0]']
#
#  average_pooling2d_26 (Aver  (None, 5, 5, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_276 (Conv2D)         (None, 5, 5, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_275 (B  (None, 5, 5, 384)            1152      ['conv2d_278[0][0]']
#  atchNormalization)
#
#  batch_normalization_276 (B  (None, 5, 5, 384)            1152      ['conv2d_279[0][0]']
#  atchNormalization)
#
#  batch_normalization_279 (B  (None, 5, 5, 384)            1152      ['conv2d_282[0][0]']
#  atchNormalization)
#
#  batch_normalization_280 (B  (None, 5, 5, 384)            1152      ['conv2d_283[0][0]']
#  atchNormalization)
#
#  conv2d_284 (Conv2D)         (None, 5, 5, 192)            393216    ['average_pooling2d_26[0][0]']
#
#  batch_normalization_273 (B  (None, 5, 5, 320)            960       ['conv2d_276[0][0]']
#  atchNormalization)
#
#  activation_275 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_275[0][0
#  )                                                                  ]']
#
#  activation_276 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_276[0][0
#  )                                                                  ]']
#
#  activation_279 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_279[0][0
#  )                                                                  ]']
#
#  activation_280 (Activation  (None, 5, 5, 384)            0         ['batch_normalization_280[0][0
#  )                                                                  ]']
#
#  batch_normalization_281 (B  (None, 5, 5, 192)            576       ['conv2d_284[0][0]']
#  atchNormalization)
#
#  activation_273 (Activation  (None, 5, 5, 320)            0         ['batch_normalization_273[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 5, 5, 768)            0         ['activation_275[0][0]',
#                                                                      'activation_276[0][0]']
#
#  concatenate_5 (Concatenate  (None, 5, 5, 768)            0         ['activation_279[0][0]',
#  )                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation  (None, 5, 5, 192)            0         ['batch_normalization_281[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 5, 5, 2048)           0         ['activation_273[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_5[0][0]',
#                                                                      'activation_281[0][0]']
#
#  global_average_pooling2d_2  (None, 2048)                 0         ['mixed10[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_6 (Dense)             (None, 1024)                 2098176   ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_7 (Dense)             (None, 3)                    3075      ['dense_6[0][0]']
#
# ==================================================================================================
# Total params: 23904035 (91.19 MB)
# Trainable params: 2101251 (8.02 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
# Compile the model
model.compile(
 loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
 optimizer="adam",
 metrics=["accuracy"]
)

# %%
import time
start_time=time.time()
history= model.fit(
  train_set,
  validation_data=val_set,
  epochs=60,
  steps_per_epoch=len(train_set),
  validation_steps=len(val_set)
)
end_time=time.time()
elapsed_time=end_time=start_time
print(f"Elapsed time: {elapsed_time} seconds")
# Out:
# Epoch 1/60
# 12/12 [==============================] - 77s 6s/step - loss: 81.9886 - accuracy: 0.3389 - val_loss: 18.4987 - val_accuracy: 0.3506
# Epoch 2/60
# 12/12 [==============================] - 62s 5s/step - loss: 17.0199 - accuracy: 0.5098 - val_loss: 6.0209 - val_accuracy: 0.6364
# Epoch 3/60
# 12/12 [==============================] - 68s 6s/step - loss: 6.0426 - accuracy: 0.6303 - val_loss: 4.1594 - val_accuracy: 0.6883
# Epoch 4/60
# 12/12 [==============================] - 59s 5s/step - loss: 3.7578 - accuracy: 0.6723 - val_loss: 5.3250 - val_accuracy: 0.6623
# Epoch 5/60
# 12/12 [==============================] - 60s 5s/step - loss: 3.5261 - accuracy: 0.7031 - val_loss: 1.4073 - val_accuracy: 0.8182
# Epoch 6/60
# 12/12 [==============================] - 55s 5s/step - loss: 1.6245 - accuracy: 0.8179 - val_loss: 1.0147 - val_accuracy: 0.8312
# Epoch 7/60
# 12/12 [==============================] - 58s 5s/step - loss: 1.3855 - accuracy: 0.8039 - val_loss: 3.6017 - val_accuracy: 0.6494
# Epoch 8/60
# 12/12 [==============================] - 60s 5s/step - loss: 2.0572 - accuracy: 0.7339 - val_loss: 1.6135 - val_accuracy: 0.7792
# Epoch 9/60
# 12/12 [==============================] - 68s 6s/step - loss: 1.5408 - accuracy: 0.7843 - val_loss: 2.2824 - val_accuracy: 0.7532
# Epoch 10/60
# 12/12 [==============================] - 59s 5s/step - loss: 1.3567 - accuracy: 0.7983 - val_loss: 0.9433 - val_accuracy: 0.8052
# Epoch 11/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.6622 - accuracy: 0.8824 - val_loss: 0.9491 - val_accuracy: 0.8312
# Epoch 12/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.6553 - accuracy: 0.8655 - val_loss: 0.5602 - val_accuracy: 0.9091
# Epoch 13/60
# 12/12 [==============================] - 58s 5s/step - loss: 0.6902 - accuracy: 0.8655 - val_loss: 1.7424 - val_accuracy: 0.7143
# Epoch 14/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.6638 - accuracy: 0.8852 - val_loss: 1.8842 - val_accuracy: 0.7662
# Epoch 15/60
# 12/12 [==============================] - 60s 5s/step - loss: 0.6615 - accuracy: 0.8571 - val_loss: 1.0592 - val_accuracy: 0.8182
# Epoch 16/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.6141 - accuracy: 0.8739 - val_loss: 0.6449 - val_accuracy: 0.8701
# Epoch 17/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.4390 - accuracy: 0.9104 - val_loss: 0.6732 - val_accuracy: 0.8442
# Epoch 18/60
# 12/12 [==============================] - 62s 5s/step - loss: 0.6205 - accuracy: 0.8711 - val_loss: 0.9536 - val_accuracy: 0.8312
# Epoch 19/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.5866 - accuracy: 0.8768 - val_loss: 0.7471 - val_accuracy: 0.8442
# Epoch 20/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.5303 - accuracy: 0.8992 - val_loss: 0.6621 - val_accuracy: 0.8442
# Epoch 21/60
# 12/12 [==============================] - 55s 5s/step - loss: 0.7015 - accuracy: 0.8431 - val_loss: 0.4366 - val_accuracy: 0.8831
# Epoch 22/60
# 12/12 [==============================] - 60s 5s/step - loss: 0.7225 - accuracy: 0.8599 - val_loss: 4.6590 - val_accuracy: 0.6104
# Epoch 23/60
# 12/12 [==============================] - 55s 5s/step - loss: 2.6820 - accuracy: 0.7199 - val_loss: 3.4488 - val_accuracy: 0.6623
# Epoch 24/60
# 12/12 [==============================] - 59s 5s/step - loss: 3.3723 - accuracy: 0.6779 - val_loss: 2.0865 - val_accuracy: 0.7532
# Epoch 25/60
# 12/12 [==============================] - 57s 5s/step - loss: 1.8753 - accuracy: 0.7899 - val_loss: 0.7806 - val_accuracy: 0.8571
# Epoch 26/60
# 12/12 [==============================] - 56s 5s/step - loss: 1.1918 - accuracy: 0.8375 - val_loss: 2.3857 - val_accuracy: 0.7013
# Epoch 27/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.9670 - accuracy: 0.8459 - val_loss: 1.2612 - val_accuracy: 0.8052
# Epoch 28/60
# 12/12 [==============================] - 67s 6s/step - loss: 1.1267 - accuracy: 0.8095 - val_loss: 2.6313 - val_accuracy: 0.7143
# Epoch 29/60
# 12/12 [==============================] - 56s 5s/step - loss: 1.3216 - accuracy: 0.8319 - val_loss: 1.2741 - val_accuracy: 0.8182
# Epoch 30/60
# 12/12 [==============================] - 60s 5s/step - loss: 0.5092 - accuracy: 0.8992 - val_loss: 0.9545 - val_accuracy: 0.8182
# Epoch 31/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.3138 - accuracy: 0.9244 - val_loss: 1.0155 - val_accuracy: 0.8312
# Epoch 32/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.3949 - accuracy: 0.9188 - val_loss: 1.2926 - val_accuracy: 0.8312
# Epoch 33/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.8006 - accuracy: 0.8627 - val_loss: 1.7489 - val_accuracy: 0.7662
# Epoch 34/60
# 12/12 [==============================] - 57s 5s/step - loss: 1.1037 - accuracy: 0.8263 - val_loss: 0.8786 - val_accuracy: 0.8052
# Epoch 35/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.5790 - accuracy: 0.8852 - val_loss: 0.5936 - val_accuracy: 0.8831
# Epoch 36/60
# 12/12 [==============================] - 62s 5s/step - loss: 0.3627 - accuracy: 0.9272 - val_loss: 0.7707 - val_accuracy: 0.8831
# Epoch 37/60
# 12/12 [==============================] - 55s 5s/step - loss: 0.4442 - accuracy: 0.8992 - val_loss: 0.5504 - val_accuracy: 0.8831
# Epoch 38/60
# 12/12 [==============================] - 56s 4s/step - loss: 0.6054 - accuracy: 0.8880 - val_loss: 1.2444 - val_accuracy: 0.8182
# Epoch 39/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.4648 - accuracy: 0.9048 - val_loss: 0.4335 - val_accuracy: 0.9091
# Epoch 40/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.3217 - accuracy: 0.9216 - val_loss: 0.6912 - val_accuracy: 0.8442
# Epoch 41/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.5496 - accuracy: 0.8824 - val_loss: 0.4799 - val_accuracy: 0.9091
# Epoch 42/60
# 12/12 [==============================] - 67s 5s/step - loss: 0.1815 - accuracy: 0.9440 - val_loss: 0.7442 - val_accuracy: 0.8571
# Epoch 43/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.5548 - accuracy: 0.8796 - val_loss: 1.4568 - val_accuracy: 0.7792
# Epoch 44/60
# 12/12 [==============================] - 56s 5s/step - loss: 2.0208 - accuracy: 0.7563 - val_loss: 4.7503 - val_accuracy: 0.6753
# Epoch 45/60
# 12/12 [==============================] - 57s 5s/step - loss: 1.9815 - accuracy: 0.7759 - val_loss: 1.0285 - val_accuracy: 0.8182
# Epoch 46/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.9507 - accuracy: 0.8571 - val_loss: 0.8871 - val_accuracy: 0.8571
# Epoch 47/60
# 12/12 [==============================] - 60s 5s/step - loss: 0.4118 - accuracy: 0.9188 - val_loss: 1.2799 - val_accuracy: 0.7792
# Epoch 48/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.2378 - accuracy: 0.9412 - val_loss: 0.4574 - val_accuracy: 0.8831
# Epoch 49/60
# 12/12 [==============================] - 68s 6s/step - loss: 0.1977 - accuracy: 0.9524 - val_loss: 0.6353 - val_accuracy: 0.8312
# Epoch 50/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.1517 - accuracy: 0.9608 - val_loss: 0.4498 - val_accuracy: 0.8701
# Epoch 51/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.0753 - accuracy: 0.9776 - val_loss: 0.4021 - val_accuracy: 0.8701
# Epoch 52/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.1270 - accuracy: 0.9524 - val_loss: 0.3469 - val_accuracy: 0.9221
# Epoch 53/60
# 12/12 [==============================] - 57s 5s/step - loss: 0.3365 - accuracy: 0.9188 - val_loss: 0.6442 - val_accuracy: 0.8701
# Epoch 54/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.1841 - accuracy: 0.9496 - val_loss: 0.4226 - val_accuracy: 0.8831
# Epoch 55/60
# 12/12 [==============================] - 56s 4s/step - loss: 0.1728 - accuracy: 0.9524 - val_loss: 0.8075 - val_accuracy: 0.8571
# Epoch 56/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.5205 - accuracy: 0.8908 - val_loss: 1.3873 - val_accuracy: 0.8052
# Epoch 57/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.3379 - accuracy: 0.9160 - val_loss: 0.6555 - val_accuracy: 0.8442
# Epoch 58/60
# 12/12 [==============================] - 56s 5s/step - loss: 0.1997 - accuracy: 0.9524 - val_loss: 0.3402 - val_accuracy: 0.9221
# Epoch 59/60
# 12/12 [==============================] - 67s 5s/step - loss: 0.2483 - accuracy: 0.9300 - val_loss: 0.5266 - val_accuracy: 0.8571
# Epoch 60/60
# 12/12 [==============================] - 59s 5s/step - loss: 0.0826 - accuracy: 0.9720 - val_loss: 0.3366 - val_accuracy: 0.8961
# Elapsed time: 1714721752.5450897 seconds

# %%
# Extract the metrics from the history object
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot the results
plt.figure(figsize=(14, 8))
plt.subplot(1, 2, 1)
plt.plot(range(len(acc)), acc, label='Training Accuracy',color='red')
plt.plot(range(len(acc)), val_acc, label='Validation Accuracy',color='blue')
plt.xlabel('No of Epochs')
plt.ylabel('Training Accuracy & Validation Accuracy')
plt.title('Visualization of Training Accuracy & Validation Accuracy Result')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(len(loss)), loss, label='Training Accuracy',color='red')
plt.plot(range(len(val_loss)), val_loss, label='Validation Accuracy',color='blue')
plt.xlabel('No of Epochs')
plt.ylabel('Training Loss & Validation Loss')
plt.title('Visualization of Training Loss & Validation Loss Result')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
loss,accuracy=model.evaluate(train_set)
accuracy*100

# %%
val_loss,val_accuracy=model.evaluate(val_set)
val_accuracy*100

# %%
test_loss,test_accuracy=model.evaluate(test_set)
test_accuracy*100

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i])
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
import numpy as np
for images_batch, labels_batch in test_set:

    first_image = images_batch[0]
    first_label = int(labels_batch[0])

    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",class_names[first_label])

    batch_prediction = model.predict(images_batch)
    print("predicted label:",class_names[np.argmax(batch_prediction[0])])
    break

# %%
plt.figure(figsize=(15, 15))
for images, labels in test_set:
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])

        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[int(labels[i])]

        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")

        plt.axis("off")
    break

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# Make predictions on a subset of the test set
subset_size = 100  # Adjust the subset size as needed
test_images_subset, test_labels_subset = [], []
for images, labels in test_set:
    if len(test_images_subset) < subset_size:
        test_images_subset.extend(images)
        test_labels_subset.extend(labels)
    else:
        break
test_images_subset = np.array(test_images_subset)
test_labels_subset = np.array(test_labels_subset)

# Generate predictions
print("Generating predictions...")
y_pred_subset = model.predict(test_images_subset)
y_pred_classes_subset = np.argmax(y_pred_subset, axis=1)

# Generate classification report
class_names = ['adenocarcinoma', 'benign', 'squamous_carcinoma']  # Replace with your class names
print("Classification Report:")
print(classification_report(test_labels_subset, y_pred_classes_subset, target_names=class_names))

# Generate confusion matrix
print("Generating confusion matrix...")
cm_subset = confusion_matrix(test_labels_subset, y_pred_classes_subset)
plt.figure(figsize=(10, 7))
sns.heatmap(cm_subset, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
